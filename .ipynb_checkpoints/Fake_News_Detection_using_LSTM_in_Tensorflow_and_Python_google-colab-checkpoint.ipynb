# %% [markdown]
# ## 1. Importing all the Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from wordcloud import WordCloud

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.12

# %%
# !python3 --version
# Out:
# Python 3.7.12

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Conv1D, MaxPool1D
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# ## 2. Exploring Fake News

# %%
fake = pd.read_csv('/content/drive/MyDrive/data/Fake.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
fake.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
fake['subject'].value_counts()
# Out:
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: subject, dtype: int64

# %%
fake['subject'].unique()
# Out:
# array(['News', 'politics', 'Government News', 'left-news', 'US_News',
#        'Middle-east'], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='subject',data=fake)

# %% [markdown]
# WordCloud for Fake news

# %%
type(fake['text'].tolist())
# Out:
# list

# %%
text = ' '.join(fake['text'].tolist())

# %%
wordcloud = WordCloud(width=1920, height=1080).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# From above word cloud we can see the words which are mostly repeated in context of fake news
# Most repeated words are United States America , now , Donald Trump since the dataset used for analysis is from US

# %% [markdown]
# ### 3. Exploring Fake News

# %%
real = pd.read_csv('/content/drive/MyDrive/data/True.csv')

# %%
real.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
real.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
real['subject'].value_counts()
# Out:
# politicsNews    11272
# worldnews       10145
# Name: subject, dtype: int64

# %% [markdown]
# WordCloud for Real News

# %%
text = ' '.join(real['text'].tolist())

# %%
wordcloud = WordCloud(width=1920, height=1080).generate(text)
fig = plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# From above WordCloud we can see that most repeated words are Washington Reuters, Reuters President and more, from this we can say that publishers are most repeated in Real news

# %%
sns.countplot(x='subject',data=real)

# %%
real.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %% [markdown]
# ## Difference in Text
# Real news seem to have source of publication which is not present in fake news set
# Looking at the Data:
# - Most of text contains reuters information such as "WASHINGTON (Reuters)".
# - Some text are tweets from Twitter
# - Few text do not contain any publication info

# %% [markdown]
# ## Cleaning Data
# Removing Reuters or Twitter Tweet information from the text
# - Text can be splitted only once at "-" which is always present after mentioning source of publication, this gives us publication part and text part
# - If we do not get text part, this means publication details was't given for the record
# - The Twitter tweets always have same source, a long text of max 256 characters.

# %%
real.sample(5)
# Out:
#                                                    title  \
# 6403   White House assails Trump 'secrecy' on financi...
# 13953  Freed Pakistani militant rails against India, ...
# 7169   Trump considering Petraeus, others for Pentago...
# 13229  Syrian, Russian jets bomb residential areas in...
# 8329   FBI to give media some Clinton notes over emai...
#
#                                                     text       subject  \
# 6403   WASHINGTON (Reuters) - The White House on Wedn...  politicsNews
# 13953  LAHORE/ISLAMABAD (Reuters) - A newly freed Pak...     worldnews
# 7169   (Reuters) - U.S. President-elect Donald Trump ...  politicsNews
# 13229  AMMAN (Reuters) - Jets believed to be Syrian a...     worldnews
# 8329   WASHINGTON (Reuters) - The FBI plans to hand o...  politicsNews
#
#                      date
# 6403    January 11, 2017
# 13953  November 24, 2017
# 7169   November 18, 2016
# 13229   December 4, 2017
# 8329     August 30, 2016

# %%
# Making a new columns for unKnown_publishers i.e. not having any publisher information by splitting the real news by '-'
unknown_publishers = []
for index, row in enumerate(real.text.values):
    try:
        # Publisher is mentioned in record and taking zeroth column
        record = row.split('-',maxsplit=1)
        # printing the record with index 1 if not present then it will give error
        record[1]
        # Assertions are simply boolean expressions that check if the conditions return true or not. 
        # If it is true, the program does nothing and moves to the next line of code. However, if it's false, the program stops and throws an error.
        assert(len(record[0])<120)
    except:
        unknown_publishers.append(index)

# %%
len(unknown_publishers)
# Out:
# 222

# %%
real.iloc[unknown_publishers].text
# Out:
# 7        The following statements were posted to the ve...
# 8        The following statements were posted to the ve...
# 12       The following statements were posted to the ve...
# 13       The following statements were posted to the ve...
# 14        (In Dec. 25 story, in second paragraph, corre...
#                                ...
# 20135     (Story corrects to million from billion in pa...
# 20500     (This Sept 8 story corrects headline, clarifi...
# 20667     (Story refiles to add dropped word  not , in ...
# 21246     (Story corrects third paragraph to show Mosul...
# 21339     (Story corrects to fix spelling in paragraph ...
# Name: text, Length: 222, dtype: object

# %%
# Since row 8970 has no data so dropping it
real.iloc[8970]
real = real.drop(8970, axis=0)

# %%
real.shape
# Out:
# (21416, 4)

# %%
# From text column removing name of publisher and appending in publisher column
# Texts having no publisher then in then appending 'unknown' in publisher column
# Texts having publisher then in then appending 'publisher name' in publisher column

publisher = []
tmp_text = []

for index, row in enumerate(real.text.values):
    if index in unknown_publishers:
        tmp_text.append(row)
        publisher.append('Unknown')
    else:
        record = row.split('-', maxsplit=1)
        publisher.append(record[0].strip())
        tmp_text.append(record[1].strip())

# %%
real['publisher'] = publisher
real['text'] = tmp_text

# %%
real.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  The head of a conservative Republican faction ...  politicsNews
# 1  Transgender people will be allowed for the fir...  politicsNews
# 2  The special counsel investigation of links bet...  politicsNews
# 3  Trump campaign adviser George Papadopoulos tol...  politicsNews
# 4  President Donald Trump called on the U.S. Post...  politicsNews
#
#                  date                     publisher
# 0  December 31, 2017           WASHINGTON (Reuters)
# 1  December 29, 2017           WASHINGTON (Reuters)
# 2  December 31, 2017           WASHINGTON (Reuters)
# 3  December 30, 2017           WASHINGTON (Reuters)
# 4  December 29, 2017   SEATTLE/WASHINGTON (Reuters)

# %%
real.shape
# Out:
# (21416, 5)

# %%
# For fake news in some rows the text data is empty and only title is present means the Title is the only content
empty_fake_index = [index for index,text in enumerate(fake.text.tolist()) if str(text).strip() == ""]

# %%
len(empty_fake_index)
# Out:
# 630

# %%
# Merging the text and title columns in one
real['text'] = real['title'] + " " + real['text']
fake['text'] = fake['title'] + " " + fake['text']

# %%
# Converting the data to lower case
real['text'] = real['text'].apply(lambda x:str(x).lower())
fake['text'] = fake['text'].apply(lambda x:str(x).lower())

# %% [markdown]
# ## 4. Preprocessing Text

# %%
# Since Fake news classifier is Supervised Machine Learning Problem so adding labels 
real['class'] = 1
fake['class'] = 0

# %% [markdown]
# Combining both Fake and Real Dataset

# %%
real.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'publisher', 'class'], dtype='object')

# %%
real = real[['text','class']]

# %%
fake = fake[['text','class']]

# %%
data = real.append(fake, ignore_index=True)

# %%
data.shape
# Out:
# (44897, 2)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 39090  classless clintons spew coordinated lies again...      0
# 31742  art contest winner disqualified for being a tr...      0
# 37573  awesome! sean spicer gives trump’s salary away...      0
# 32176  live stream: president trump’s remarks at a wr...      0
# 38962  just in: mueller’s “right hand man” represente...      0

# %% [markdown]
# ## Vectorization - Word2Vec
#
# Word2Vec is one of the most popular technique to learn word embeddings using shallow neural network
# Word embedding is the most popular representation of document vocabulary. It is capable of capturing context of word in a document semantic and syntactic, relation with other words,etc.
#
# <img src="https://th.bing.com/th/id/R.85dad8627ae6845b62f5bb965c291b19?rik=DK3U9M0C6y4weg&riu=http%3a%2f%2fjalammar.github.io%2fimages%2fword2vec%2fword2vec.png&ehk=l2HKjP2OyoOZzn3PanqJIxSM5nG7sgwwvQ6R702QxvE%3d&risl=&pid=ImgRaw&r=0" width='50%'>
#
# <img src="https://www.samyzaf.com/ML/nlp/word2vec2.png" width='50%'>

# %% [markdown]
# # 5. Using Gensim Library for word2vec

# %%
# !pip install gensim

# %%
import gensim # for converting words to vector
from gensim.models import Word2Vec

# %%
y = data['class'].values

# %%
# Converting all the texts to list 
X = [d.split() for d in data['text'].tolist()]

# %%
w2v_model = Word2Vec(sentences=X, window=10, min_count=1)

# %%
len(w2v_model.wv.vocab)
# Out:
# 375373

# %%
similar = w2v_model.wv.most_similar('india')

# %%
similar
# Out:
# [('malaysia', 0.7272761464118958),
#  ('pakistan', 0.7223309278488159),
#  ('china', 0.7058124542236328),
#  ('pakistan,', 0.6863403916358948),
#  ('beijing', 0.6858519315719604),
#  ('india,', 0.6837332248687744),
#  ('china,', 0.675940752029419),
#  ('beijing’s', 0.6677294969558716),
#  ('china’s', 0.6587281227111816),
#  ('philippines', 0.6498199701309204)]

# %%
w2v_model.wv['india']
# Out:
# array([ 0.4491012 , -0.75229186,  0.97248065,  0.3703258 , -2.4266665 ,
#        -1.0089201 ,  1.3960998 ,  0.2837856 , -1.0838368 , -0.901774  ,
#         3.2549956 , -0.22197635,  1.6971738 , -2.4518058 , -0.09078122,
#        -0.6040616 ,  2.3587408 , -0.70767105,  1.8447131 , -0.66696984,
#         0.9861718 ,  2.500493  , -0.9619462 , -0.81060815, -2.2710981 ,
#         0.4969467 ,  0.13060108, -1.9078574 , -0.52666396, -3.2649314 ,
#         1.545429  , -4.4344897 ,  0.95581067,  1.4827166 ,  0.9254237 ,
#        -0.28487477, -0.42279395, -0.51280355,  1.0578612 , -0.31530106,
#        -0.7022916 , -1.5918583 , -0.49593565, -1.2547027 ,  0.9234852 ,
#         0.30914342, -1.6030561 , -1.3349046 , -0.8827217 ,  0.580398  ,
#        -1.1810014 ,  1.2119814 , -2.4270642 ,  0.54850674,  2.1561606 ,
#        -0.13946982, -1.0268255 , -1.7332157 , -1.7609129 ,  0.322676  ,
#        -1.6926016 , -2.6282547 ,  0.263512  ,  2.1287806 ,  0.25662246,
#         0.30104   , -2.762671  , -1.8281575 , -1.6526368 ,  1.6079929 ,
#         2.393884  , -0.3447315 , -0.28185317,  0.25179106,  0.80091137,
#        -0.6272819 , -2.4154227 , -1.3541982 , -0.02247024,  0.40561843,
#         0.22600989, -0.3804995 , -1.3192126 , -0.69659436, -2.3409846 ,
#        -0.72326   , -0.5724213 ,  2.1948056 ,  0.28250965,  1.2752078 ,
#        -1.5293871 ,  0.24582604, -2.1136794 ,  0.08798845,  1.7729434 ,
#        -1.1215488 , -0.6001765 , -1.3635699 ,  1.3918375 ,  0.4951048 ],
#       dtype=float32)

# %% [markdown]
# # 6. Preprocessing the data

# %%
# Tokenizer will remove special characters and converts the characters to lower case
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)

# %%
X = tokenizer.texts_to_sequences(X)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'to': 2,
#  'of': 3,
#  'a': 4,
#  'and': 5,
#  'in': 6,
#  'that': 7,
#  'on': 8,
#  'for': 9,
#  's': 10,
#  'is': 11,
#  'he': 12,
#  'with': 13,
#  'was': 14,
#  'it': 15,
#  'trump': 16,
#  'as': 17,
#  'his': 18,
#  'by': 19,
#  'said': 20,
#  'has': 21,
#  'be': 22,
#  'have': 23,
#  'from': 24,
#  'not': 25,
#  'at': 26,
#  'are': 27,
#  'this': 28,
#  'who': 29,
#  'an': 30,
#  'they': 31,
#  'but': 32,
#  'would': 33,
#  'we': 34,
#  'i': 35,
#  'about': 36,
#  'u.s.': 37,
#  'will': 38,
#  'their': 39,
#  'president': 40,
#  'had': 41,
#  'been': 42,
#  'you': 43,
#  't': 44,
#  'were': 45,
#  'or': 46,
#  'after': 47,
#  'which': 48,
#  'more': 49,
#  'she': 50,
#  'people': 51,
#  'her': 52,
#  'one': 53,
#  'if': 54,
#  'what': 55,
#  'when': 56,
#  'new': 57,
#  'out': 58,
#  'all': 59,
#  'its': 60,
#  'also': 61,
#  'over': 62,
#  'donald': 63,
#  'state': 64,
#  'no': 65,
#  'up': 66,
#  'our': 67,
#  'there': 68,
#  'can': 69,
#  'said.': 70,
#  'just': 71,
#  'than': 72,
#  'house': 73,
#  'other': 74,
#  'some': 75,
#  'could': 76,
#  'republican': 77,
#  'obama': 78,
#  'into': 79,
#  'told': 80,
#  'united': 81,
#  'government': 82,
#  'white': 83,
#  'so': 84,
#  'against': 85,
#  'clinton': 86,
#  'like': 87,
#  'because': 88,
#  'last': 89,
#  'any': 90,
#  'do': 91,
#  'him': 92,
#  'two': 93,
#  'how': 94,
#  'only': 95,
#  'states': 96,
#  'news': 97,
#  'former': 98,
#  'first': 99,
#  'should': 100,
#  'even': 101,
#  'being': 102,
#  'campaign': 103,
#  'hillary': 104,
#  'while': 105,
#  'during': 106,
#  'them': 107,
#  'did': 108,
#  'many': 109,
#  'before': 110,
#  'most': 111,
#  'party': 112,
#  'national': 113,
#  'political': 114,
#  'time': 115,
#  'may': 116,
#  'now': 117,
#  'get': 118,
#  'make': 119,
#  'those': 120,
#  'made': 121,
#  'security': 122,
#  'where': 123,
#  'since': 124,
#  'american': 125,
#  'us': 126,
#  'going': 127,
#  'police': 128,
#  'presidential': 129,
#  'under': 130,
#  'media': 131,
#  'these': 132,
#  'say': 133,
#  'election': 134,
#  'democratic': 135,
#  'north': 136,
#  'trump’s': 137,
#  'court': 138,
#  'very': 139,
#  'between': 140,
#  'republicans': 141,
#  'including': 142,
#  'back': 143,
#  'according': 144,
#  'support': 145,
#  'take': 146,
#  'says': 147,
#  'think': 148,
#  'federal': 149,
#  'foreign': 150,
#  'such': 151,
#  'senate': 152,
#  're': 153,
#  'bill': 154,
#  'called': 155,
#  'percent': 156,
#  'my': 157,
#  'country': 158,
#  'then': 159,
#  'law': 160,
#  'down': 161,
#  'public': 162,
#  'don': 163,
#  'military': 164,
#  'want': 165,
#  'officials': 166,
#  'administration': 167,
#  'years': 168,
#  'tax': 169,
#  'russia': 170,
#  'group': 171,
#  '-': 172,
#  'know': 173,
#  'million': 174,
#  'russian': 175,
#  'your': 176,
#  'vote': 177,
#  'department': 178,
#  'both': 179,
#  'year': 180,
#  'still': 181,
#  'way': 182,
#  'another': 183,
#  'via': 184,
#  'much': 185,
#  'through': 186,
#  'see': 187,
#  'right': 188,
#  'america': 189,
#  'part': 190,
#  'saying': 191,
#  'minister': 192,
#  'washington': 193,
#  'asked': 194,
#  'own': 195,
#  'black': 196,
#  'go': 197,
#  'world': 198,
#  'next': 199,
#  'why': 200,
#  'secretary': 201,
#  'image': 202,
#  'need': 203,
#  'office': 204,
#  'whether': 205,
#  'three': 206,
#  'work': 207,
#  'democrats': 208,
#  'off': 209,
#  'help': 210,
#  'trump,': 211,
#  'never': 212,
#  'video': 213,
#  'official': 214,
#  'women': 215,
#  'congress': 216,
#  'senator': 217,
#  'week': 218,
#  'said,': 219,
#  'general': 220,
#  'took': 221,
#  'around': 222,
#  'rights': 223,
#  'use': 224,
#  'every': 225,
#  'does': 226,
#  'policy': 227,
#  'without': 228,
#  'same': 229,
#  'city': 230,
#  'used': 231,
#  'come': 232,
#  'china': 233,
#  'put': 234,
#  'top': 235,
#  'leader': 236,
#  'war': 237,
#  'americans': 238,
#  'well': 239,
#  'statement': 240,
#  'here': 241,
#  'nuclear': 242,
#  'day': 243,
#  'fbi': 244,
#  'deal': 245,
#  'show': 246,
#  'really': 247,
#  'man': 248,
#  'members': 249,
#  'intelligence': 250,
#  'york': 251,
#  'good': 252,
#  'left': 253,
#  'order': 254,
#  'end': 255,
#  'south': 256,
#  'international': 257,
#  'several': 258,
#  'korea': 259,
#  'candidate': 260,
#  'committee': 261,
#  '2016': 262,
#  'already': 263,
#  'report': 264,
#  'meeting': 265,
#  'trade': 266,
#  'justice': 267,
#  '.': 268,
#  'must': 269,
#  'long': 270,
#  'me': 271,
#  'john': 272,
#  'likely': 273,
#  'among': 274,
#  'social': 275,
#  'conservative': 276,
#  'fox': 277,
#  'tuesday': 278,
#  'islamic': 279,
#  'barack': 280,
#  'case': 281,
#  'got': 282,
#  'might': 283,
#  'chief': 284,
#  'attack': 285,
#  'recent': 286,
#  'money': 287,
#  'leaders': 288,
#  'came': 289,
#  'information': 290,
#  'major': 291,
#  'director': 292,
#  'business': 293,
#  'power': 294,
#  'wednesday': 295,
#  'call': 296,
#  'health': 297,
#  'thursday': 298,
#  'believe': 299,
#  'twitter': 300,
#  'iran': 301,
#  've': 302,
#  'plan': 303,
#  'it.': 304,
#  'decision': 305,
#  'trying': 306,
#  'something': 307,
#  'won': 308,
#  'didn': 309,
#  'number': 310,
#  'least': 311,
#  'family': 312,
#  'seen': 313,
#  'times': 314,
#  'muslim': 315,
#  'friday': 316,
#  'move': 317,
#  'found': 318,
#  'voters': 319,
#  'investigation': 320,
#  'went': 321,
#  'however,': 322,
#  'economic': 323,
#  'change': 324,
#  'monday': 325,
#  'making': 326,
#  'clear': 327,
#  'become': 328,
#  'keep': 329,
#  'give': 330,
#  'm': 331,
#  'far': 332,
#  'senior': 333,
#  'doesn': 334,
#  'until': 335,
#  'working': 336,
#  'countries': 337,
#  'actually': 338,
#  'little': 339,
#  'too': 340,
#  'press': 341,
#  'executive': 342,
#  'set': 343,
#  'interview': 344,
#  'killed': 345,
#  'let': 346,
#  'legal': 347,
#  'reported': 348,
#  'speech': 349,
#  'four': 350,
#  'immigration': 351,
#  'great': 352,
#  'supporters': 353,
#  'free': 354,
#  'big': 355,
#  'groups': 356,
#  'spokesman': 357,
#  'days': 358,
#  'border': 359,
#  'defense': 360,
#  'look': 361,
#  'story': 362,
#  'european': 363,
#  'reuters': 364,
#  'stop': 365,
#  'few': 366,
#  '[video]': 367,
#  'taking': 368,
#  'agency': 369,
#  'real': 370,
#  'prime': 371,
#  'local': 372,
#  'billion': 373,
#  'human': 374,
#  'eu': 375,
#  'supreme': 376,
#  'control': 377,
#  'across': 378,
#  'member': 379,
#  'earlier': 380,
#  'following': 381,
#  'things': 382,
#  'sanders': 383,
#  'known': 384,
#  'held': 385,
#  'place': 386,
#  'post': 387,
#  'illegal': 388,
#  'home': 389,
#  'march': 390,
#  'doing': 391,
#  'wants': 392,
#  'governor': 393,
#  'nothing': 394,
#  'gop': 395,
#  'pay': 396,
#  'democrat': 397,
#  'financial': 398,
#  'attorney': 399,
#  'given': 400,
#  'win': 401,
#  'fact': 402,
#  'continue': 403,
#  'ever': 404,
#  'school': 405,
#  'head': 406,
#  'opposition': 407,
#  'lawmakers': 408,
#  'expected': 409,
#  'past': 410,
#  'released': 411,
#  'syrian': 412,
#  'judge': 413,
#  'months': 414,
#  'taken': 415,
#  'attacks': 416,
#  '&': 417,
#  'issue': 418,
#  'having': 419,
#  'once': 420,
#  'gun': 421,
#  'yet': 422,
#  'special': 423,
#  'cruz': 424,
#  'away': 425,
#  'high': 426,
#  'forces': 427,
#  'cnn': 428,
#  'using': 429,
#  'children': 430,
#  'talks': 431,
#  'himself': 432,
#  'private': 433,
#  'syria': 434,
#  'matter': 435,
#  'despite': 436,
#  'later': 437,
#  'force': 438,
#  'woman': 439,
#  'close': 440,
#  'lot': 441,
#  'accused': 442,
#  'month': 443,
#  'trump.': 444,
#  'better': 445,
#  'able': 446,
#  'open': 447,
#  'sanctions': 448,
#  'care': 449,
#  'though': 450,
#  'saudi': 451,
#  'watch': 452,
#  'second': 453,
#  'wall': 454,
#  'thing': 455,
#  'anyone': 456,
#  'fight': 457,
#  '“i': 458,
#  'important': 459,
#  'july': 460,
#  'person': 461,
#  'men': 462,
#  'program': 463,
#  'possible': 464,
#  'evidence': 465,
#  'behind': 466,
#  'act': 467,
#  'find': 468,
#  'run': 469,
#  'companies': 470,
#  'early': 471,
#  'january': 472,
#  'along': 473,
#  'air': 474,
#  'comes': 475,
#  'full': 476,
#  'images': 477,
#  'violence': 478,
#  'current': 479,
#  '“the': 480,
#  'u.n.': 481,
#  'reporters': 482,
#  'face': 483,
#  'due': 484,
#  'within': 485,
#  'civil': 486,
#  'response': 487,
#  'nation': 488,
#  'plans': 489,
#  'point': 490,
#  'company': 491,
#  'less': 492,
#  'enough': 493,
#  'calling': 494,
#  'five': 495,
#  'budget': 496,
#  'team': 497,
#  'majority': 498,
#  'someone': 499,
#  'best': 500,
#  'getting': 501,
#  'further': 502,
#  'lead': 503,
#  'congressional': 504,
#  'action': 505,
#  'role': 506,
#  'june': 507,
#  'll': 508,
#  'year,': 509,
#  'ban': 510,
#  'nominee': 511,
#  'sunday': 512,
#  'reports': 513,
#  'email': 514,
#  'efforts': 515,
#  'nearly': 516,
#  'global': 517,
#  'sent': 518,
#  'mr.': 519,
#  'university': 520,
#  'system': 521,
#  'comments': 522,
#  'lives': 523,
#  'it,': 524,
#  'allow': 525,
#  'hard': 526,
#  'thousands': 527,
#  'calls': 528,
#  'young': 529,
#  'legislation': 530,
#  'nations': 531,
#  'announced': 532,
#  'union': 533,
#  'coming': 534,
#  'whose': 535,
#  'community': 536,
#  'others': 537,
#  'running': 538,
#  'led': 539,
#  'refugees': 540,
#  'done': 541,
#  'climate': 542,
#  'anything': 543,
#  'death': 544,
#  'paul': 545,
#  'gave': 546,
#  'live': 547,
#  'visit': 548,
#  'latest': 549,
#  'middle': 550,
#  'that,': 551,
#  'ryan': 552,
#  'each': 553,
#  'states,': 554,
#  'makes': 555,
#  'daily': 556,
#  'election.': 557,
#  'question': 558,
#  'job': 559,
#  'issues': 560,
#  'sure': 561,
#  'wanted': 562,
#  ',': 563,
#  'source': 564,
#  'isn': 565,
#  'tell': 566,
#  'hold': 567,
#  'again': 568,
#  'am': 569,
#  'effort': 570,
#  'talk': 571,
#  'debate': 572,
#  'putin': 573,
#  'coalition': 574,
#  'letter': 575,
#  'staff': 576,
#  'fake': 577,
#  'outside': 578,
#  'needs': 579,
#  'facebook': 580,
#  'ties': 581,
#  'today': 582,
#  'criminal': 583,
#  'late': 584,
#  'liberal': 585,
#  'army': 586,
#  'sources': 587,
#  'conference': 588,
#  'central': 589,
#  'chairman': 590,
#  'sexual': 591,
#  'comey': 592,
#  'students': 593,
#  'george': 594,
#  'almost': 595,
#  'britain': 596,
#  'meet': 597,
#  'tried': 598,
#  'claims': 599,
#  'november': 600,
#  'began': 601,
#  'showed': 602,
#  'speaking': 603,
#  'failed': 604,
#  'healthcare': 605,
#  'wrote': 606,
#  'cut': 607,
#  'cannot': 608,
#  'try': 609,
#  'voting': 610,
#  'start': 611,
#  'based': 612,
#  'future': 613,
#  'planned': 614,
#  'council': 615,
#  'service': 616,
#  'everyone': 617,
#  '10': 618,
#  'means': 619,
#  'lost': 620,
#  'states.': 621,
#  'bring': 622,
#  'millions': 623,
#  'received': 624,
#  'access': 625,
#  'protect': 626,
#  'hope': 627,
#  'entire': 628,
#  'ruling': 629,
#  'allowed': 630,
#  'rather': 631,
#  'key': 632,
#  'stand': 633,
#  'six': 634,
#  'd': 635,
#  'provide': 636,
#  'leave': 637,
#  'life': 638,
#  'decided': 639,
#  'street': 640,
#  'comment': 641,
#  'election,': 642,
#  'near': 643,
#  'name': 644,
#  'year.': 645,
#  'process': 646,
#  'line': 647,
#  'statement.': 648,
#  'agreement': 649,
#  'night': 650,
#  'chinese': 651,
#  'immediately': 652,
#  'center': 653,
#  'april': 654,
#  'thought': 655,
#  'race': 656,
#  '“we': 657,
#  'different': 658,
#  'always': 659,
#  'talking': 660,
#  'authorities': 661,
#  'often': 662,
#  'missile': 663,
#  'history': 664,
#  'questions': 665,
#  'mexico': 666,
#  'vice': 667,
#  'poll': 668,
#  'iraq': 669,
#  'december': 670,
#  'host': 671,
#  'met': 672,
#  'rules': 673,
#  'ahead': 674,
#  'looking': 675,
#  'instead': 676,
#  'weapons': 677,
#  'ministry': 678,
#  'bad': 679,
#  'votes': 680,
#  'oil': 681,
#  'citizens': 682,
#  'james': 683,
#  'october': 684,
#  'message': 685,
#  'threat': 686,
#  'muslims': 687,
#  'kind': 688,
#  'shows': 689,
#  'week,': 690,
#  'release': 691,
#  'funding': 692,
#  'strong': 693,
#  'include': 694,
#  'crisis': 695,
#  'people,': 696,
#  'voted': 697,
#  'korean': 698,
#  'position': 699,
#  'peace': 700,
#  'israel': 701,
#  'especially': 702,
#  'rule': 703,
#  'texas': 704,
#  'denied': 705,
#  'officers': 706,
#  'emails': 707,
#  'british': 708,
#  'relations': 709,
#  'potential': 710,
#  'him.': 711,
#  'rally': 712,
#  'reason': 713,
#  'western': 714,
#  'terrorist': 715,
#  'seems': 716,
#  'bernie': 717,
#  'candidates': 718,
#  'small': 719,
#  'event': 720,
#  'read': 721,
#  'list': 722,
#  'jobs': 723,
#  'now,': 724,
#  'personal': 725,
#  'agreed': 726,
#  'travel': 727,
#  'representative': 728,
#  'representatives': 729,
#  'spending': 730,
#  'alleged': 731,
#  'idea': 732,
#  'although': 733,
#  'weeks': 734,
#  'conservatives': 735,
#  'large': 736,
#  'obama’s': 737,
#  'recently': 738,
#  'workers': 739,
#  'february': 740,
#  'years,': 741,
#  'september': 742,
#  'old': 743,
#  'leading': 744,
#  'hate': 745,
#  'racist': 746,
#  'shot': 747,
#  'enforcement': 748,
#  'biggest': 749,
#  'needed': 750,
#  'energy': 751,
#  'hit': 752,
#  'august': 753,
#  'bush': 754,
#  'main': 755,
#  'involved': 756,
#  'worked': 757,
#  'said:': 758,
#  'east': 759,
#  'fighting': 760,
#  'arrested': 761,
#  'them.': 762,
#  'probably': 763,
#  'president,': 764,
#  'nov.': 765,
#  'appeared': 766,
#  'spoke': 767,
#  'district': 768,
#  'concerns': 769,
#  'services': 770,
#  'fire': 771,
#  'everything': 772,
#  'saturday': 773,
#  'paid': 774,
#  'reform': 775,
#  'michael': 776,
#  'final': 777,
#  'clinton,': 778,
#  'claimed': 779,
#  'feel': 780,
#  'century': 781,
#  'turkey': 782,
#  'organization': 783,
#  'agencies': 784,
#  'wasn': 785,
#  'mike': 786,
#  'elected': 787,
#  'brought': 788,
#  'capital': 789,
#  '2015': 790,
#  'toward': 791,
#  'step': 792,
#  'region': 793,
#  '...': 794,
#  'declined': 795,
#  'turned': 796,
#  'immigrants': 797,
#  'country.': 798,
#  'shooting': 799,
#  'claim': 800,
#  'became': 801,
#  'front': 802,
#  'pressure': 803,
#  'officer': 804,
#  'ted': 805,
#  'serious': 806,
#  'request': 807,
#  'freedom': 808,
#  'time,': 809,
#  '(video)': 810,
#  'charges': 811,
#  'myanmar': 812,
#  'allegations': 813,
#  'west': 814,
#  'germany': 815,
#  '20': 816,
#  'return': 817,
#  'fired': 818,
#  'issued': 819,
#  'confirmed': 820,
#  'passed': 821,
#  'simply': 822,
#  'forced': 823,
#  'allies': 824,
#  'spent': 825,
#  'problem': 826,
#  'parties': 827,
#  'j.': 828,
#  'posted': 829,
#  'adding': 830,
#  'bank': 831,
#  'deputy': 832,
#  'love': 833,
#  'david': 834,
#  'people.': 835,
#  'goes': 836,
#  'water': 837,
#  'protesters': 838,
#  'german': 839,
#  'religious': 840,
#  'signed': 841,
#  'sign': 842,
#  'seeking': 843,
#  'giving': 844,
#  'push': 845,
#  'pretty': 846,
#  'included': 847,
#  'together': 848,
#  'address': 849,
#  'obamacare': 850,
#  'popular': 851,
#  'parliament': 852,
#  'helped': 853,
#  'raised': 854,
#  'saw': 855,
#  '8': 856,
#  'hours': 857,
#  'clearly': 858,
#  'documents': 859,
#  'attempt': 860,
#  'years.': 861,
#  'room': 862,
#  'gets': 863,
#  'turn': 864,
#  'previously': 865,
#  'building': 866,
#  'policies': 867,
#  'proposed': 868,
#  'started': 869,
#  'insurance': 870,
#  'described': 871,
#  'regional': 872,
#  'hundreds': 873,
#  'mark': 874,
#  'al': 875,
#  'either': 876,
#  'state,': 877,
#  'economy': 878,
#  'half': 879,
#  'happened': 880,
#  'largest': 881,
#  'data': 882,
#  'elections': 883,
#  'discuss': 884,
#  'review': 885,
#  'armed': 886,
#  'added': 887,
#  'tuesday,': 888,
#  'florida': 889,
#  'college': 890,
#  '21st': 891,
#  'repeatedly': 892,
#  'campaign,': 893,
#  'criticized': 894,
#  'secret': 895,
#  'voter': 896,
#  'aid': 897,
#  'country,': 898,
#  'mayor': 899,
#  'robert': 900,
#  'laws': 901,
#  'tillerson': 902,
#  'similar': 903,
#  'wire': 904,
#  'cia': 905,
#  'northern': 906,
#  'created': 907,
#  'build': 908,
#  'remain': 909,
#  'increase': 910,
#  'situation': 911,
#  'county': 912,
#  'speaker': 913,
#  'mass': 914,
#  'cost': 915,
#  'longer': 916,
#  'pass': 917,
#  'themselves': 918,
#  'single': 919,
#  'actions': 920,
#  'influence': 921,
#  'side': 922,
#  'protest': 923,
#  'ask': 924,
#  'interest': 925,
#  'tweet': 926,
#  'hearing': 927,
#  'total': 928,
#  '2017': 929,
#  'course,': 930,
#  'speak': 931,
#  'ambassador': 932,
#  'it’s': 933,
#  'third': 934,
#  'seven': 935,
#  'board': 936,
#  'telling': 937,
#  'friday,': 938,
#  'commission': 939,
#  'currently': 940,
#  'primary': 941,
#  'respond': 942,
#  'adviser': 943,
#  'town': 944,
#  'whole': 945,
#  'violent': 946,
#  'refugee': 947,
#  'market': 948,
#  'independent': 949,
#  'article': 950,
#  'don’t': 951,
#  'warned': 952,
#  'heard': 953,
#  'mainstream': 954,
#  'medical': 955,
#  'dollars': 956,
#  'san': 957,
#  'well,': 958,
#  'california': 959,
#  'iraqi': 960,
#  'living': 961,
#  'published': 962,
#  'industry': 963,
#  'appears': 964,
#  'merkel': 965,
#  'takes': 966,
#  'president.': 967,
#  'lawyer': 968,
#  'record': 969,
#  'words': 970,
#  'previous': 971,
#  'seek': 972,
#  'him,': 973,
#  'area': 974,
#  'is,': 975,
#  'cases': 976,
#  'stay': 977,
#  'polls': 978,
#  'asking': 979,
#  'victory': 980,
#  'protests': 981,
#  'consider': 982,
#  'southern': 983,
#  'kurdish': 984,
#  'politics': 985,
#  'soon': 986,
#  'food': 987,
#  'prevent': 988,
#  'leadership': 989,
#  'forward': 990,
#  'focus': 991,
#  'movement': 992,
#  'fear': 993,
#  'result': 994,
#  'moscow': 995,
#  'urged': 996,
#  'fellow': 997,
#  'crime': 998,
#  'phone': 999,
#  'child': 1000,
#  ...}

# %% [markdown]
# Analysis the text data since most of news range between 600 to 1400 so taking maxelngth of news as 1050

# %%
plt.hist([len(x) for x in X],bins=700)
plt.show()

# %% [markdown]
# Since we can see that most of the data or text are less than 1000 words so ignore data have more than 1000 words data

# %%
nos = np.array([len(x) for x in X])
len(nos[nos>1050])
# Out:
# 1381

# %%
maxlen = 1050
X = pad_sequences(X,maxlen=maxlen)

# %%
X[0]
# Out:
# array([   0,    0,    0, ...,    8,    1, 9441], dtype=int32)

# %%
# Adding +1 for unknown words
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 375374

# %%
DIM = 100
vocab = tokenizer.word_index
def get_weight_matrix(model):
    weight_matrix = np.zeros((vocab_size, DIM))
    
    for word,i in vocab.items():
        weight_matrix[i] = model.wv[word]
    
    return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
embedding_vectors.shape
# Out:
# (375374, 100)

# %% [markdown]
# # 7. Creating model using word embedding and lSTM in Deep learning

# %%
model = Sequential()
model.add(Embedding(vocab_size, output_dim=DIM, weights=[embedding_vectors], input_length=maxlen, trainable=False))
model.add(LSTM(units=128))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 1050, 100)         37537400
#
#  lstm_1 (LSTM)               (None, 128)               117248
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 37,654,777
# Trainable params: 117,377
# Non-trainable params: 37,537,400
# _________________________________________________________________

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=5)
# Out:
# Epoch 1/5
# 737/737 [==============================] - 61s 73ms/step - loss: 0.1369 - acc: 0.9486 - val_loss: 0.0891 - val_acc: 0.9694
# Epoch 2/5
# 737/737 [==============================] - 50s 67ms/step - loss: 0.0741 - acc: 0.9746 - val_loss: 0.0643 - val_acc: 0.9782
# Epoch 3/5
# 737/737 [==============================] - 52s 71ms/step - loss: 0.0417 - acc: 0.9868 - val_loss: 0.0393 - val_acc: 0.9853
# Epoch 4/5
# 737/737 [==============================] - 50s 67ms/step - loss: 0.0270 - acc: 0.9908 - val_loss: 0.0302 - val_acc: 0.9896
# Epoch 5/5
# 737/737 [==============================] - 50s 67ms/step - loss: 0.0263 - acc: 0.9908 - val_loss: 0.0233 - val_acc: 0.9920

# %%
# Accuracy on Test Dataset
y_pred = (model.predict(X_test) >= 0.5).astype(int)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9923385300668152

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5948
#            1       0.99      0.99      0.99      5277
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %% [markdown]
# # 8. How to  classify on custom data

# %%
x = ['Govt making efforts to obtain files relating to Netaji: MoS Muraleedharan in Rajya Sabha']
x = tokenizer.texts_to_sequences(x)
x = pad_sequences(x,maxlen=1050)
(model.predict(x) >=0.5).astype(int)
# Out:
# array([[0]])

# %%
x=['''The Minister said in the Rajya Sabha that the UK has informed that 62 files on Bose are already available on the websites of the National Archives and the British Library.MoS Muraleedharan was replying to a question on the governments efforts to seek cooperation relating to the controversy over Netaji's death.
The Russian Government had informed the government of India that they were unable to find any documents in the Russian archives pertaining to Netaji. "The Russian government said that additional investigations were made to find the documents, based on request from the Indian side," he said.
ALSO READ: PM Modi unveils hologram statue of Netaji Subhas Chandra Bose at India Gate
The Japanese government has declassified two files on Netaji. "These files are part of their Archives and are available in the public domain. The government of Japan has transferred these files to India and they are retained in the National Archives of India," the minister said.
Muraleedharan informed the government of Japan has also said that if there are any additional documents relevant to the matter, those would be declassified as per their policies after a prescribed time period and based on an internal review mechanism.''']

# %%
x = tokenizer.texts_to_sequences(x)
print(x)
x = pad_sequences(x,maxlen=1050)
print(x)
(model.predict(x) >=0.5).astype(int)
# Out:
# [[1, 192, 20, 6, 1, 48382, 7, 1, 1551, 21, 2779, 7, 10426, 2635, 8, 27, 263, 1650, 8, 1, 5158, 3, 1, 113, 7979, 5, 1, 708, 8060, 113659, 14, 37818, 2, 4, 558, 8, 1, 1632, 515, 2, 972, 1561, 7731, 2, 1, 2406, 62, 544, 1, 175, 82, 41, 2779, 1, 82, 3, 2343, 7, 31, 45, 1954, 2, 468, 90, 859, 6, 1, 175, 7979, 14056, 2, 1, 175, 82, 20, 7, 1198, 1809, 45, 121, 2, 468, 1, 859, 612, 8, 807, 24, 1, 2876, 922, 12, 20, 61, 721, 1693, 5563, 19495, 201882, 5280, 3, 43419, 26, 2343, 9170, 1, 2188, 82, 21, 13032, 93, 2635, 8, 132, 2635, 27, 190, 3, 39, 7979, 5, 27, 1650, 6, 1, 162, 11646, 1, 82, 3, 1350, 21, 6589, 132, 2635, 2, 2343, 5, 31, 27, 10801, 6, 1, 113, 7979, 3, 2343, 1, 192, 20, 2779, 1, 82, 3, 1350, 21, 61, 20, 7, 54, 68, 27, 90, 1198, 859, 3792, 2, 1, 435, 120, 33, 22, 13032, 17, 1213, 39, 867, 47, 4, 17328, 115, 1690, 5, 612, 8, 30, 1609, 885, 6948]]
# [[   0    0    0 ... 1609  885 6948]]
# array([[1]])

# %%
from joblib import dump, load
dump(model, 'wordToVec_lstm_Model.joblib')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://4067043f-5fa5-44e0-8014-664051b91eb8/assets
# INFO:tensorflow:Assets written to: ram://4067043f-5fa5-44e0-8014-664051b91eb8/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe6358d0e50> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# ['wordToVec_lstm_Model.joblib']

# %%
from joblib import dump, load
import numpy as np
model_lstm = load('wordToVec_lstm_Model.joblib') 

x = ['Govt making efforts to obtain files relating to Netaji: MoS Muraleedharan in Rajya Sabha']
x = tokenizer.texts_to_sequences(x)
x = pad_sequences(x,maxlen=1050)
(model_lstm.predict(x) >=0.5).astype(int)
# model_lstm.predict(x)
# Out:
# WARNING:tensorflow:6 out of the last 360 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe63506ec20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 360 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe63506ec20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[0]])

# %%
from joblib import dump, load
import numpy as np
model_lstm = load('wordToVec_lstm_Model.joblib') 

x = [''' The Karnataka High Court on Thursday said that it is considering whether wearing a Hijab comes within Fundamental Rights. "We are considering the issue of whether the wearing of headscarf comes within the Fundamental Rights. We are also considering whether wearing a headscarf is an essential part of the religious practice," a three-judge bench headed by Chief Justice Ritu Raj Awasthi said while hearing petitions questioning the ban on the wearing of hijabs by students in schools and colleges. Senior advocate Devdatt Kamat, appearing for the petitioners from Kundapura, said that there is an urgency in the case and "requested that some interim arrangement be worked out by this bench" as students' exams are to be held in March. Earlier on Wednesday, Justice Krishna S Dixit, who was hearing the case, referred the petitions to a larger bench citing constitutional questions. Meanwhile, police in Delhi detained All India Students Association (AISA) workers who were marching towards Karnataka Bhawan to protest against the Karnataka government's dress code order.
considering the seriousness of the situation and to prevent the confrontation in Bengaluru, the administration has clamped prohibitory orders for two weeks. The hijab protests began last month at the Government Girls PU College in Udupi when students alleged that they had been barred from classes for insisting on wearing hijab. Protests for and against the 'hijab' then intensified in different parts of Karnataka and turned violent in some places.  
''']
x = tokenizer.texts_to_sequences(x)
x = pad_sequences(x,maxlen=1050)
(model_lstm.predict(x) >=0.5).astype(int)
# Out:
# WARNING:tensorflow:5 out of the last 359 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe64a4cbb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 359 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe64a4cbb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[1]])
